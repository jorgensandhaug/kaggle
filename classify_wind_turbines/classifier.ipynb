# %%
from autogluon.multimodal import MultiModalPredictor
from autogluon.tabular import TabularDataset
train = TabularDataset("train.csv")
test = TabularDataset("val.csv")
# Out:
# Loaded data from: train.csv | Columns = 2 / 2 | Rows = 357507 -> 357507
# Loaded data from: val.csv | Columns = 2 / 2 | Rows = 71504 -> 71504

# %%
predictor = MultiModalPredictor(label="class", problem_type="classification")
predictor.fit(train, time_limit=60*60*2, presets="best_quality")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 predictor = MultiModalPredictor(label="class", problem_type="classification")                │
# │ ❱ 2 predictor.set_num_gpus(1)                                                                    │
# │   3                                                                                              │
# │                                                                                                  │
# │ /Users/jorgensandhaug/.local/lib/python3.10/site-packages/autogluon/multimodal/predictor.py:1893 │
# │ in set_num_gpus                                                                                  │
# ...

# %%
predictions = predictor.predict(test[:100])
predictions
# Out:
# /Users/jorgensandhaug/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]
# 0         target
# 1         target
# 2         target
# 3         target
# 4     background
#          ...
# 95    background
# 96        target
# 97    background
# 98        target
# 99    background
# Name: class, Length: 100, dtype: object

# %%
from IPython.display import display, HTML

# Initialize HTML string with some CSS for styling
html_str = """
<style>
    .image-grid {
        display: grid;
        grid-template-columns: repeat(4, 1fr);
        gap: 16px;
        justify-items: center;
    }
    .image-cell {
        text-align: center;
    }
</style>
<div class="image-grid">
"""

# Loop through the predictions
for i, pred in predictions.items():
    image_path = test.loc[i]['image_path']
    html_str += f"""
    <div class="image-cell">
        <img src="{image_path}" alt="Image {i}" width="100">
        <p>Predicted class: {pred}</p>
    </div>
    """

# Close the main div
html_str += "</div>"

# Display the HTML content
display(HTML(html_str))
# Out:
# <style>
#     .image-grid {
#         display: grid;
#         grid-template-columns: repeat(4, 1fr);
#         gap: 16px;
#         justify-items: center;
#     }
#     .image-cell {
#         text-align: center;
#     }
# </style>
# <div class="image-grid">
#
#     <div class="image-cell">
#         <img src="/Users/jorgensandhaug/Documents/github_documents/automl/classify_wind_turbines/archive/val/background/737f75b1-7d0b-4a72-b322-52548a42220f.jpg" alt="Image 0" width="100">
#         <p>Predicted class: target</p>
#     </div>
#
#     <div class="image-cell">
#         <img src="/Users/jorgensandhaug/Documents/github_documents/automl/classify_wind_turbines/archive/val/background/ef3424ab-7216-43fd-9ca8-b0b704b49ab3.jpg" alt="Image 1" width="100">
#         <p>Predicted class: target</p>
#     </div>
#
#     <div class="image-cell">
# ...

# %%
# test
predictor.evaluate(test)
# Out:
# /Users/jorgensandhaug/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]
# {'accuracy': 0.20967741935483872}
